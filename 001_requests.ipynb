# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic


client = Anthropic()
model = "claude-sonnet-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)



def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Make a starting list of messages
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    #  Add in initial user question of "Define quantum computing in one sentence."
    add_user_message(messages, user_input)

    # Pass the list of messages into the 'chat' to get an answer
    answer = chat(messages)

    # Take the answer and add it as an assistnt message into our list
    add_assistant_message(messages, answer)

    print("---")
    print(answer)
    print("---")
# Out:
# >  hvad er 1 + 1 ?
# ---
# **1 + 1 = 2**
#
# Er der noget mere, du gerne vil vide? 😊
# ---
# >  hvad hvis man tilføjer 2?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 12
#       8     #  Add in initial user question of "Define quantum computing in one sentence."
#       9     add_user_message(messages, user_input)
#      10
#      11     # Pass the list of messages into the 'chat' to get an answer
# ---> 12     answer = chat(messages)
#      13
#      14     # Take the answer and add it as an assistnt message into our list
#      15     add_assistant_message(messages, answer)
#
# Cell In[45], line 17, in chat(messages)
#      13         model=model,
#      14         max_tokens=1000,
#      15         messages=messages,
#      16     )
# ---> 17     return message.content[0].text
#
# File ~\digitalventures\courses\claudecourses\.venv\Lib\site-packages\pydantic\main.py:1042, in BaseModel.__getattr__(self, item)
#    1039     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1040 else:
#    1041     # this is the current error
# -> 1042     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ThinkingBlock' object has no attribute 'text'
