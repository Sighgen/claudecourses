# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic


client = Anthropic()
model = "claude-sonnet-5"

# %%
# Make a request
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ]
)

# %%
message.content[0].text
# Out:
# "The capital of France is **Paris**.\n\nIt's the country's largest city and serves as its political, economic, and cultural center. Paris is known for landmarks such as the Eiffel Tower, the Louvre Museum, Notre-Dame Cathedral, and the Champs-Élysées."
